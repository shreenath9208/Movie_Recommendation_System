# %%
import pandas as pd 
import numpy as np 
import ast

# %%
movie1=pd.read_csv("tmdb_5000_movies.csv")
movie2=pd.read_csv("tmdb_5000_credits.csv")

# %%
movie1.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movie1.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
movie1.shape
# Out:
# (4803, 20)

# %%
movie2.columns
# Out:
# Index(['movie_id', 'title', 'cast', 'crew'], dtype='object')

# %%
movie1=movie1.merge(movie2,on='title')

# %%
movie1.shape
# Out:
# (4809, 23)

# %%
movie1.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
# ...

# %%
movie=movie1[['movie_id','title','cast','crew','overview','keywords','genres']]

# %%
movie.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4809 non-null   int64
#  1   title     4809 non-null   object
#  2   cast      4809 non-null   object
#  3   crew      4809 non-null   object
#  4   overview  4806 non-null   object
#  5   keywords  4809 non-null   object
#  6   genres    4809 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 263.1+ KB

# %%
movie.isnull().sum()
# Out:
# movie_id    0
# title       0
# cast        0
# crew        0
# overview    3
# keywords    0
# genres      0
# dtype: int64

# %%
movie.dropna(inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2720\4265595405.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie.dropna(inplace=True)

# %%
movie.isnull().sum()
# Out:
# movie_id    0
# title       0
# cast        0
# crew        0
# overview    0
# keywords    0
# genres      0
# dtype: int64

# %%
movie.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
type(movie['crew'][0])
# Out:
# str

# %%
type(ast.literal_eval(movie['crew'][0]))
# Out:
# list

# %%
def fetch_director(obj):
    L= []
    for i in ast.literal_eval(obj):
        if i['job']=='Director':
            L.append(i['name'])
    return L

# %%
movie['crew']=movie['crew'].apply(fetch_director)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2720\3259542168.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['crew']=movie['crew'].apply(fetch_director)

# %%
len(movie['crew'])
# Out:
# 4806

# %%
movie['crew'][1]
# Out:
# ['Gore Verbinski']

# %%
print(movie.duplicated)
# Out:
# <bound method DataFrame.duplicated of       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4804      9367                               El Mariachi
# 4805     72766                                 Newlyweds
# 4806    231617                 Signed, Sealed, Delivered
# 4807    126186                          Shanghai Calling
# 4808     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
def converter(obj):
    L=[]
    for i in ast.literal_eval(obj):
        L.append(i['name'])
    return L

# %%
movie['genres'].head()
# Out:
# 0    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1    [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3    [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# Name: genres, dtype: object

# %%
movie['keywords']
# Out:
# 0       [{"id": 1463, "name": "culture clash"}, {"id":...
# 1       [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2       [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3       [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4       [{"id": 818, "name": "based on novel"}, {"id":...
#                               ...
# 4804    [{"id": 5616, "name": "united states\u2013mexi...
# 4805                                                   []
# 4806    [{"id": 248, "name": "date"}, {"id": 699, "nam...
# 4807                                                   []
# 4808    [{"id": 1523, "name": "obsession"}, {"id": 224...
# Name: keywords, Length: 4806, dtype: object

# %%
movie['genres']=movie['genres'].apply(converter)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2720\2252788094.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['genres']=movie['genres'].apply(converter)

# %%
movie['keywords']=movie['keywords'].apply(converter)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2720\1949482954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['keywords']=movie['keywords'].apply(converter)

# %%
movie.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast                 crew  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...      [James Cameron]
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...     [Gore Verbinski]
# 2  [{"cast_id": 1, "character": "James Bond", "cr...         [Sam Mendes]
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...  [Christopher Nolan]
# 4  [{"cast_id": 5, "character": "John Carter", "c...     [Andrew Stanton]
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# ...

# %%
movie['cast'][0]
# Out:
# '[{"cast_id": 242, "character": "Jake Sully", "credit_id": "5602a8a7c3a3685532001c9a", "gender": 2, "id": 65731, "name": "Sam Worthington", "order": 0}, {"cast_id": 3, "character": "Neytiri", "credit_id": "52fe48009251416c750ac9cb", "gender": 1, "id": 8691, "name": "Zoe Saldana", "order": 1}, {"cast_id": 25, "character": "Dr. Grace Augustine", "credit_id": "52fe48009251416c750aca39", "gender": 1, "id": 10205, "name": "Sigourney Weaver", "order": 2}, {"cast_id": 4, "character": "Col. Quaritch", "credit_id": "52fe48009251416c750ac9cf", "gender": 2, "id": 32747, "name": "Stephen Lang", "order": 3}, {"cast_id": 5, "character": "Trudy Chacon", "credit_id": "52fe48009251416c750ac9d3", "gender": 1, "id": 17647, "name": "Michelle Rodriguez", "order": 4}, {"cast_id": 8, "character": "Selfridge", "credit_id": "52fe48009251416c750ac9e1", "gender": 2, "id": 1771, "name": "Giovanni Ribisi", "order": 5}, {"cast_id": 7, "character": "Norm Spellman", "credit_id": "52fe48009251416c750ac9dd", "gender"
# ...

# %%
type(movie['cast'][0])
# Out:
# str

# %% [markdown]
# ast.literal_eval(obj) for your understanding purpose we are converting the string expression into its original form by using this code

# %%
def cast(obj):
    L=[]
    C = 0
    for i in ast.literal_eval(obj):
        if C != 3:
            L.append(i['name'])
            C +=1
        else:
            break
    return L

# %%
movie['cast']=movie['cast'].apply(cast)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2720\2054084518.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['cast']=movie['cast'].apply(cast)

# %%
movie['cast'][0]
# Out:
# ['Sam Worthington', 'Zoe Saldana', 'Sigourney Weaver']

# %%
movie.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                cast                 crew  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]      [James Cameron]
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]     [Gore Verbinski]
# 2      [Daniel Craig, Christoph Waltz, Léa Seydoux]         [Sam Mendes]
# 3      [Christian Bale, Michael Caine, Gary Oldman]  [Christopher Nolan]
# 4    [Taylor Kitsch, Lynn Collins, Samantha Morton]     [Andrew Stanton]
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# ...

# %%
# movie['cast']=movie['cast'].apply(lambda x:  [i.replace(" ","")])
movie['cast']=movie['cast'].apply(lambda x:[i.replace(" ","")for i in x ])
movie['keywords']=movie['keywords'].apply(lambda x:[i.replace(" ","")for i in x ])

movie['crew']=movie['crew'].apply(lambda x:[i.replace(" ","")for i in x ])

movie['genres']=movie['genres'].apply(lambda x:[i.replace(" ","")for i in x ])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2720\2311962196.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['cast']=movie['cast'].apply(lambda x:[i.replace(" ","")for i in x ])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2720\2311962196.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['keywords']=movie['keywords'].apply(lambda x:[i.replace(" ","")for i in x ])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2720\2311962196.py:5: SettingWithCopyWarning:
# ...

# %%
movie.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             cast                crew  \
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]     [GoreVerbinski]
# 2      [DanielCraig, ChristophWaltz, LéaSeydoux]         [SamMendes]
# 3      [ChristianBale, MichaelCaine, GaryOldman]  [ChristopherNolan]
# 4    [TaylorKitsch, LynnCollins, SamanthaMorton]     [AndrewStanton]
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# ...

# %%
movie['overview'][0]
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'

# %%
movie['overview']=movie['overview'].apply(lambda x :x.split())
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2720\464898674.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['overview']=movie['overview'].apply(lambda x :x.split())

# %%
movie['overview'][0]
# Out:
# ['In',
#  'the',
#  '22nd',
#  'century,',
#  'a',
#  'paraplegic',
#  'Marine',
#  'is',
#  'dispatched',
#  'to',
#  'the',
#  'moon',
#  'Pandora',
#  'on',
#  'a',
#  'unique',
#  'mission,',
#  'but',
#  'becomes',
#  'torn',
#  'between',
#  'following',
#  'orders',
#  'and',
#  'protecting',
#  'an',
#  'alien',
#  'civilization.']

# %%
movie['tags']=movie['cast']+ movie['crew']+movie['genres']+movie['keywords']+movie['overview']
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2720\1983634126.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['tags']=movie['cast']+ movie['crew']+movie['genres']+movie['keywords']+movie['overview']

# %%
movie.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             cast                crew  \
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]     [GoreVerbinski]
# 2      [DanielCraig, ChristophWaltz, LéaSeydoux]         [SamMendes]
# 3      [ChristianBale, MichaelCaine, GaryOldman]  [ChristopherNolan]
# 4    [TaylorKitsch, LynnCollins, SamanthaMorton]     [AndrewStanton]
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# ...

# %%
movie1=movie[['movie_id','title','tags']]

# %%
movie1.shape
# Out:
# (4806, 3)

# %%
movie1.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver, ...
# 1  [JohnnyDepp, OrlandoBloom, KeiraKnightley, Gor...
# 2  [DanielCraig, ChristophWaltz, LéaSeydoux, SamM...
# 3  [ChristianBale, MichaelCaine, GaryOldman, Chri...
# 4  [TaylorKitsch, LynnCollins, SamanthaMorton, An...

# %%
movie1['tags']=movie1['tags'].apply(lambda x:" ".join(x))
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2720\56026110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie1['tags']=movie1['tags'].apply(lambda x:" ".join(x))

# %%
movie1['tags'][0]
# Out:
# 'SamWorthington ZoeSaldana SigourneyWeaver JamesCameron Action Adventure Fantasy ScienceFiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'

# %%
movie1.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  SamWorthington ZoeSaldana SigourneyWeaver Jame...
# 1  JohnnyDepp OrlandoBloom KeiraKnightley GoreVer...
# 2  DanielCraig ChristophWaltz LéaSeydoux SamMende...
# 3  ChristianBale MichaelCaine GaryOldman Christop...
# 4  TaylorKitsch LynnCollins SamanthaMorton Andrew...

# %%
print(movie1['tags'][0])
# Out:
# SamWorthington ZoeSaldana SigourneyWeaver JamesCameron Action Adventure Fantasy ScienceFiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.

# %%
movie1['tags']=movie1['tags'].apply(lambda x : x.lower() )
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2720\2930250990.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie1['tags']=movie1['tags'].apply(lambda x : x.lower() )

# %%
movie1.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  samworthington zoesaldana sigourneyweaver jame...
# 1  johnnydepp orlandobloom keiraknightley gorever...
# 2  danielcraig christophwaltz léaseydoux sammende...
# 3  christianbale michaelcaine garyoldman christop...
# 4  taylorkitsch lynncollins samanthamorton andrew...

# %%
import nltk
from nltk.stem.porter import PorterStemmer

# %%
ps = PorterStemmer()

# %%
def stemmer(text):
    y =[]
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
movie1['tags']=movie1['tags'].apply(stemmer)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2720\1147775415.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie1['tags']=movie1['tags'].apply(stemmer)

# %% [markdown]
# By using the above code we get the words in the root form

# %%
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vectors=cv.fit_transform(movie1['tags']).toarray()

# %%
vectors.ndim
# Out:
# 2

# %%
len(vectors)
# Out:
# 4806

# %%
vectors.shape
# Out:
# (4806, 5000)

# %%
cv.get_feature_names_out()
# Out:
# array(['000', '007', '10', ..., 'zone', 'zoo', 'zooeydeschanel'],
#       dtype=object)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vectors)

# %%
similarity[0]
# Out:
# array([1.        , 0.08346223, 0.0860309 , ..., 0.04499213, 0.        ,
#        0.        ])

# %%
len(similarity[0])
# Out:
# 4806

# %%
print(similarity)
# Out:
# [[1.         0.08346223 0.0860309  ... 0.04499213 0.         0.        ]
#  [0.08346223 1.         0.06063391 ... 0.02378257 0.         0.02615329]
#  [0.0860309  0.06063391 1.         ... 0.02451452 0.         0.        ]
#  ...
#  [0.04499213 0.02378257 0.02451452 ... 1.         0.03962144 0.04229549]
#  [0.         0.         0.         ... 0.03962144 1.         0.08714204]
#  [0.         0.02615329 0.         ... 0.04229549 0.08714204 1.        ]]

# %%
movie1.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  samworthington zoesaldana sigourneyweav jamesc...
# 1  johnnydepp orlandobloom keiraknightley gorever...
# 2  danielcraig christophwaltz léaseydoux sammend ...
# 3  christianbal michaelcain garyoldman christophe...
# 4  taylorkitsch lynncollin samanthamorton andrews...

# %%
movie1[movie1['movie_id']==0].title
# Out:
# Series([], Name: title, dtype: object)

# %%
similarity[1]
# Out:
# array([0.08346223, 1.        , 0.06063391, ..., 0.02378257, 0.        ,
#        0.02615329])

# %%
for i in enumerate(similarity[1]):
    print(i)
# Out:
# (0, 0.08346223261119858)
# (1, 1.0)
# (2, 0.06063390625908323)
# (3, 0.03883678186903086)
# (4, 0.07504691899113898)
# (5, 0.1145873121285264)
# (6, 0.02127178149057585)
# (7, 0.1292719224987548)
# (8, 0.06262242910851494)
# (9, 0.10226199851298272)
# (10, 0.10846522890932808)
# (11, 0.07504691899113898)
# (12, 0.4140043409440133)
# (13, 0.09513029883089881)
# (14, 0.1355815361366601)
# (15, 0.1107018606925119)
# (16, 0.08346223261119858)
# (17, 0.2533201985524494)
# (18, 0.06021717344277752)
# (19, 0.1097907187727647)
# (20, 0.061357199107789626)
# (21, 0.05797710356524483)
# (22, 0.10502100630210075)
# (23, 0.09240616554505461)
# (24, 0.14097096860865022)
# (25, 0.1078676197944929)
# (26, 0.10846522890932808)
# (27, 0.08783257501821176)
# (28, 0.06160411036336974)
# (29, 0.04583492485141056)
# (30, 0.11778571185788637)
# (31, 0.10090091909944686)
# (32, 0.09007546982220897)
# (33, 0.10289915108550529)
# (34, 0.03300491809922247)
# (35, 0.10502100630210075)
# ...

# %%
movie1[movie1['movie_id']==12].title
# Out:
# 328    Finding Nemo
# Name: title, dtype: object

# %%
# movie1[movie1['title']=='Avatar'].index[0]
dist=sorted(list(enumerate(similarity[1])),reverse=True,key=lambda x : x[1])[1:11]

dist
# Out:
# [(12, 0.4140043409440133),
#  (199, 0.27500954910846337),
#  (17, 0.2533201985524494),
#  (216, 0.20579830217101058),
#  (3572, 0.20579830217101058),
#  (187, 0.18981415059132412),
#  (2135, 0.18499891602515212),
#  (848, 0.17589669862367344),
#  (1077, 0.17503501050350123),
#  (109, 0.17149858514250882)]

# %%
movie1.iloc[12].title
# Out:
# "Pirates of the Caribbean: Dead Man's Chest"

# %%
def recomendation(movie):
    movie_index=movie1[movie1['title']==movie].index[0]
    distance=similarity[movie_index]
    movies_list=sorted(list(enumerate(distance)),reverse=True,key=lambda x : x[1])[1:11]
 
    for i in movies_list:
        id= i[0]
        print(movie1.iloc[id].title)

# %%
recomendation('Aliens')
# Out:
# Alien
# Alien³
# Meet Dave
# Star Trek: Insurrection
# Escape from Planet Earth
# Alien: Resurrection
# Dragon Wars: D-War
# Avatar
# Aliens vs Predator: Requiem
# The Hitchhiker's Guide to the Galaxy

# %% [markdown]
# This is how model are done for going to get recommendation

# %%
import pickle

# %%
# This is actually the for the need in this format 
pickle.dump(movie1.to_dict(),open('movie_dict.pkl','wb'))

# %%
pickle.dump(similarity,open('similarity.pkl','wb'))

# %%
pickle.dump(movie1,open('movie.pkl','wb'))
